# %% [markdown]
# # Euler Number

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 100)
y = np.exp(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('y = e^x')
plt.show()
